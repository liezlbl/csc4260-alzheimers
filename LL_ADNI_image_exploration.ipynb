# %%
pip install nibabel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.0 -> 24.0
# [notice] To update, run: /opt/ohpc/pub/spack/v0.20.1/opt/spack/linux-rocky8-x86_64_v3/gcc-8.5.0/python-3.10.10-pfj3kn4eqy4hivj33qcmazddy3xivrld/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.listdir()
# Out:
# ['AD',
#  'CN',
#  'MCI',
#  'ad_subject_ids.txt',
#  'ADNI1_Complete_3Yr_3T_3_25_2024.csv',
#  'ADNI_IMAGES.ipynb',
#  'ADNI_images_groups.py',
#  'cn_subject_ids.txt',
#  'mci_subject_ids.txt',
#  'nii_extract.py',
#  '.ipynb_checkpoints']

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
# Out:
# 2024-03-26 19:54:59.216698: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 19:54:59.219845: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 19:54:59.261711: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-26 19:55:00.722512: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
filename = 'AD/005_S_0814/ADNI_005_S_0814_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070918114601353_S29396_I73538.nii'
test_load = nib.load(filename)
test_load.shape
header = test_load.header
print(header.get_zooms())
print(header.get_data_shape())
# Out:
# (256, 256, 166)
# (1.0292445, 1.0201486, 1.2041016)
# (256, 256, 166)

# %%
test_load_data = test_load.get_fdata()

# %%
plt.imshow(test_load_data[:, :, 96])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.imshow(test_load_data[:, :, 96])
#
# NameError: name 'test_load_data' is not defined

# %%
# sagittal plane
plt.imshow(test_load_data[:, :, 96], cmap='bone')
plt.axis('off')
plt.show()
